# %% [markdown]
# # 🌸 Task 1: Exploring and Visualizing the Iris Dataset
#
# This notebook explores the classic **Iris flower dataset** using pandas, seaborn, and matplotlib.
# We will perform:
# - Data loading and inspection
# - Summary statistics
# - Missing value checks
# - Scatter plot, histogram, and box plot visualizations

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set visualization style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# ## 📥 Load the Iris Dataset
#
# We'll load the built-in Iris dataset from seaborn and inspect it.

# %%
# Load Iris dataset
iris = sns.load_dataset("iris")

# Show shape, columns, and first few rows
print("Shape of dataset:", iris.shape)
print("Columns:", iris.columns.tolist())
iris.head()
# Out:
# Shape of dataset: (150, 5)
# Columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Summary statistics
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Out:
#   File "/tmp/ipython-input-5-1659460662.py", line 3
#     This plot helps us see how petal dimensions vary across species.
#          ^
# SyntaxError: invalid syntax

# %%
# Check for missing values
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## 📊 Scatter Plot: Petal Length vs Petal Width
#
# This plot helps us see how petal dimensions vary across species.

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width", hue="species", palette="bright")
plt.title("Scatter Plot: Petal Length vs Petal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.legend(title="Species")
plt.show()

# %%
sns.histplot(data=iris, x="sepal_length", kde=True, color="skyblue", bins=15)
plt.title("Histogram: Sepal Length Distribution")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(data=iris, x="species", y="sepal_width", palette="Set2")
plt.title("Box Plot: Sepal Width by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Width (cm)")
plt.show()
# Out:
# /tmp/ipython-input-8-2013939871.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris, x="species", y="sepal_width", palette="Set2")

# %% [markdown]
# ## ✅ Conclusion
#
# - ✅ No missing values were found.
# - ✅ The Setosa species is clearly distinct based on petal features.
# - ✅ Sepal width varies more across species than sepal length.
# - ✅ Visualizations are effective in identifying patterns in the dataset.
#
# This completes **Task 1: Iris Dataset Exploration** 🎉
